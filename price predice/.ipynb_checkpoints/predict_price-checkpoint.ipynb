# %%
import csv
import numpy as np
import pandas as pd

file_name = '../data/artwork_transactions_sample.csv'
artwork_transactions = pd.read_csv(file_name)
# Out:
# /Users/eva/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2728: DtypeWarning: Columns (8,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
def find_out_lables(column):
    lables = []
    for value in column:
        if value not in lables:
            lables.append(value)
    print(lables)
    return lables


# find_out_lables(artwork_transactions['trans_category'])
# find_out_lables(artwork_transactions['trans_art_type'])
# find_out_lables(artwork_transactions['auction_id'])
# find_out_lables(artwork_transactions['company_id'])

# %%
#drop column with no info

artwork_transactions.drop(['auction_info_link'],axis=1,inplace=True)
artwork_transactions.drop(['collector'],axis=1,inplace=True)
artwork_transactions.drop(['sell_agency'],axis=1,inplace=True)
artwork_transactions.drop(['image_url'],axis=1,inplace=True)
artwork_transactions.drop(['icon_img_url'],axis=1,inplace=True)
artwork_transactions.drop(['search_string'],axis=1,inplace=True)

artwork_transactions.drop(['eval_price_curr'],axis=1,inplace=True)        #information in eval_price
artwork_transactions.drop(['trade_curr'],axis=1,inplace=True)             #only one value
artwork_transactions.drop(['comments_count'],axis=1,inplace=True) 
artwork_transactions.drop(['likes_count'],axis=1,inplace=True) 


#删除‘未提供’价格的 row

artwork_transactions = artwork_transactions[artwork_transactions.display_price != '未提供']
artwork_transactions = artwork_transactions.reset_index()

# %%
#category fill nan

artwork_transactions['trans_category']=artwork_transactions['trans_category'].fillna('unclear')


        
#make new column artist

artist_artworktransaction_dic = pd.read_csv('artist_artworktransaction.csv')
artwork_transactions['artist'] = range(len(artwork_transactions))
for i in range(len(artwork_transactions)):
    artwork_transactions['artist'][i] = artist_artworktransaction_dic.artist_id[artist_artworktransaction_dic.artwork_transaction_id == artwork_transactions.id[i]]
# Out:
# /Users/eva/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':

# %%
# about time form transform
import datetime
import time

def texts_to_dates(texts):
    dates = []
    for text in texts:
        date = datetime.datetime.strptime(text, '%Y-%m-%d %H:%M:%S').date()
        dates.append(date)
    return dates


def texts_to_strptime(texts):
    counter =0
    dates = np.array(range(len(texts)))
    for text in texts:
        date = datetime.datetime.strptime(text, '%Y-%m-%d %H:%M:%S').date()
        date_s = time.mktime(date.timetuple())
        #print(dates[counter])
        dates[counter] = date_s
        #print (dates[:10])
        counter +=1
    #print(dates)
    return dates

def get_age_days(date1s,date2s):
    age_days=[]
    for i in range(len(date1s)):
        age_days.append((date1s[i] - date2s[i]).days)
    return age_days


artwork_transactions['transaction_date'] = texts_to_strptime(artwork_transactions.transaction_date)
artwork_transactions['transaction_date'] = (artwork_transactions['transaction_date'])

# %%
# about price
exchange_rate = {'USD':0.15831, 
                 'HKD':1.23757036, 
                 'RMB':1, 
                 'NTD':4.60471204,
                 'SGD':0.207030484,
                 'GBP':0.111719583,
                 'EUR':0.127391969
                }

eval_price = []
eval_price_min = []
eval_price_max = []
for ii, price in enumerate(artwork_transactions['eval_price']):
    if ii % 500 == 0: print(ii)
        

    if pd.isnull(price): 
        eval_price.append(0)
        eval_price_min.append(0)
        eval_price_max.append(0)
    else:
        price = price.split(' ')
        price[1] = (price[1].strip('\u3000')).split('-')
        try:
            price_min = int(price[1][0].replace(',',''))/(exchange_rate[price[0]])
        except ValueError: 
            print(price)
            price_min = 0
            
        try:
            price_max = int(price[1][1].replace(',',''))/(exchange_rate[price[0]])
        except ValueError: 
            print(price)
            price_max = 0
        
        eval_price.append(price)
        eval_price_min.append(price_min)
        eval_price_max.append(price_max)

        
artwork_transactions['eval_price_min'] = (eval_price_min)
artwork_transactions['eval_price_max'] = (eval_price_max)
artwork_transactions['eval_price'] = (artwork_transactions['eval_price_max'] + artwork_transactions['eval_price_min'])/2
# Out:
# 0
# 500
# 1000
# 1500
# 2000
# 2500
# 3000
# 3500
# 4000
# 4500
# 5000
# 5500
# 6000
# 6500
# 7000
# 7500
# 8000
# 8500
# 9000
# 9500
# 10000
# 10500
# 11000
# ['RMB', ['60,000', '']]
# 11500
# 12000
# 12500
# 13000
# 13500
# 14000
# 14500
# 15000
# 15500
# 16000
# 16500
# 17000
# 17500
# 18000
# 18500
# 19000
# 19500
# 20000
# 20500
# 21000
# 21500
# 22000
# 22500
# 23000
# 23500
# 24000
# 24500
# 25000
# 25500
# 26000
# 26500
# 27000
# 27500
# 28000
# 28500
# 29000
# 29500
# 30000
# 30500
# 31000
# 31500
# 32000
# 32500
# 33000
# 33500
# 34000
# 34500
# 35000
# 35500
# 36000
# 36500
# 37000
# 37500
# 38000
# 38500
# 39000
# 39500
# 40000
# 40500
# 41000
# 41500
# 42000
# 42500
# 43000
# ['RMB', ['16,000', '']]
# 43500
# 44000
# 44500
# 45000
# 45500
# 46000
# 46500
# 47000
# 47500
# 48000
# 48500
# 49000
# 49500
# 50000
# 50500
# 51000
# 51500
# 52000
# 52500
# 53000
# 53500
# 54000
# 54500
# 55000
# 55500
# 56000
# 56500
# 57000
# 57500
# 58000
# 58500
# 59000
# 59500
# 60000
# 60500
# 61000
# 61500
# 62000
# 62500
# 63000
# 63500
# 64000
# 64500
# 65000
# 65500
# 66000
# 66500
# 67000
# 67500
# 68000
# 68500
# 69000
# 69500
# 70000
# 70500
# 71000
# 71500
# 72000
# 72500
# 73000
# 73500
# 74000
# 74500
# 75000
# 75500
# 76000
# 76500

# %%
artwork_transactions['calc_price'] = artwork_transactions['calc_price'].fillna(0)
artwork_transactions = artwork_transactions[artwork_transactions.calc_price != 0]
artwork_transactions = artwork_transactions.reset_index()

# %% [markdown]
# ## 统计分析

# %%
artwork_transactions.head()
# Out:
#    level_0  index       id trans_type   display_price  calc_price  eval_price  \
# 0        3      6  1206654    auction     RMB 　46,000     46000.0     10000.0
# 1        4      8  2178583    auction    RMB 　107,800    107800.0     50000.0
# 2        5      9  1297817    auction  RMB 　9,200,000   9200000.0   9000000.0
# 3        6     11  2238306    auction    RMB 　115,000    115000.0    100000.0
# 4        7     12   889125    auction     RMB 　95,200     95200.0     99000.0
#
#    eval_price_min  eval_price_max trans_category   ...       info_update_time  \
# 0          8000.0         12000.0             绘画   ...    2015-07-12 01:31:41
# 1         40000.0         60000.0             书法   ...    2015-07-13 17:24:12
# 2       8000000.0      10000000.0             书法   ...    2015-07-12 04:41:37
# 3         80000.0        120000.0             绘画   ...    2015-07-13 20:20:36
# 4         78000.0        120000.0             绘画   ...    2015-07-10 18:34:38
#
#   trade_channel_id                                       origin_url  \
# 0            12120  http://auction.artron.net/paimai-art5045880074/
# 1             4779    http://auction.artron.net/paimai-art37161389/
# 2            11744  http://auction.artron.net/paimai-art0022540236/
# 3             9394  http://auction.artron.net/paimai-art5049681674/
# 4             5595    http://auction.artron.net/paimai-art96800031/
#
#             created_at           updated_at transaction_date   lot  \
# 0  2013-12-23 00:00:00  2013-12-23 00:00:00       1387641600  0074
# 1  2005-12-12 00:00:00  2005-12-12 00:00:00       1134230400  1389
# 2  2013-06-04 00:00:00  2013-06-04 00:00:00       1370188800  0236
# 3  2014-05-10 00:00:00  2014-05-10 00:00:00       1399564800  1674
# 4  2010-11-19 00:00:00  2010-11-19 00:00:00       1290009600  0031
#
#    auction_id company_id  artist
# 0        3316        129  117629
# 1        1987         72   15710
# 2         259          7   14567
# 3         666         67   42533
# 4        1798        233   47595
#
# [5 rows x 22 columns]

# %%
artwork_transactions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52704 entries, 0 to 52703
# Data columns (total 22 columns):
# level_0                 52704 non-null int64
# index                   52704 non-null int64
# id                      52704 non-null int64
# trans_type              52704 non-null object
# display_price           52704 non-null object
# calc_price              52704 non-null float64
# eval_price              52704 non-null float64
# eval_price_min          52704 non-null float64
# eval_price_max          52704 non-null float64
# trans_category          52704 non-null object
# trans_art_type          52704 non-null object
# artwork_auction_name    52704 non-null object
# info_update_time        52695 non-null object
# trade_channel_id        52704 non-null int64
# origin_url              52704 non-null object
# created_at              52704 non-null object
# updated_at              52704 non-null object
# transaction_date        52704 non-null int64
# lot                     52704 non-null object
# auction_id              52704 non-null int64
# company_id              52704 non-null int64
# artist                  52704 non-null int64
# dtypes: float64(4), int64(8), object(10)
# memory usage: 8.8+ MB

# %% [markdown]
# #### 估价的分布
#
# 艺术品估价的分布（事实上成交价格也是一样），呈现完全的倾斜状态，估价和成交价是完全相关的！我之后会先试着使用 估价 这一feature，看看能达到的准确度，但是最终的模型我并不使用估价。

# %%
print (len(artwork_transactions))
print (len(artwork_transactions[artwork_transactions.eval_price < 10000]))
print (len(artwork_transactions[artwork_transactions.eval_price > 1000000]))
# Out:
# 52704
# 17508
# 1185

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns 


plt.hist(artwork_transactions['eval_price'], range = (0,1000000))
plt.hist(artwork_transactions['eval_price'], range = (0,100000))
# Out:
# (array([ 17508.,   7682.,   4914.,   3104.,   2721.,   1989.,   1529.,
#           1407.,    682.,   1557.]),
#  array([      0.,   10000.,   20000.,   30000.,   40000.,   50000.,
#           60000.,   70000.,   80000.,   90000.,  100000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### 艺术家 和售价
#
# 艺术家和售价一定有关系的呢~

# %%
def count_lables(column):
    lables = []
    for value in column:
        if value not in lables:
            lables.append(value)
    return len(lables)

count_lables(artwork_transactions['artist'])
# Out:
# 10952

# %%
artist_price = artwork_transactions.groupby(['artist'])['calc_price'].mean()
plt.hist(artist_price,range = (0,1000000))
# Out:
# (array([ 8976.,   911.,   351.,   198.,   103.,    83.,    49.,    29.,
#            25.,    29.]),
#  array([       0.,   100000.,   200000.,   300000.,   400000.,   500000.,
#           600000.,   700000.,   800000.,   900000.,  1000000.]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# #### 艺术品的类型 和品种
#
# #### 艺术品类型 * 色彩？
#
# #### 艺术品的类型 * name
#
# #### 拍卖公司 和 拍卖会
#
# 首先，拍卖公司也许是相关的。
#
# 而拍卖会，平均每次拍卖会的艺术品也是小于十件，样本量过小。再次，待预测的艺术品一定来自于新的拍卖会，在最终的预测中是没有用的。

# %% [markdown]
# ## 准备塞进分类器

# %%
from sklearn import preprocessing
def scale(data):
    X_train = data
    X_scaled = preprocessing.scale(X_train)

    return X_scaled

# %%
def sperate_train_data(data):
    the_num_of_total_data = len(data)
    data_train = data[:int(the_num_of_total_data * 0.8)]
    data_test = data[int(the_num_of_total_data * 0.8):]
    return data_train, data_test

#feature_train, feature_test = sperate_train_data(feature_matric)

# %%
attrib = [
          'trans_cantegory',
          'trans_art_type',
          'transaction_date',
          'company_id',
          'artist']

# %%
artwork_transactions.drop(['lot'],axis=1,inplace=True)
artwork_transactions.drop(['updated_at'],axis=1,inplace=True)
artwork_transactions.drop(['created_at'],axis=1,inplace=True)
artwork_transactions.drop(['origin_url'],axis=1,inplace=True)
artwork_transactions.drop(['trade_channel_id'],axis=1,inplace=True)
artwork_transactions.drop(['info_update_time'],axis=1,inplace=True)
artwork_transactions.drop(['artwork_auction_name'],axis=1,inplace=True)
artwork_transactions.drop(['display_price'],axis=1,inplace=True)
artwork_transactions.drop(['trans_type'],axis=1,inplace=True)
artwork_transactions.drop(['id'],axis=1,inplace=True)
artwork_transactions.drop(['index'],axis=1,inplace=True)
artwork_transactions.drop(['level_0'],axis=1,inplace=True)

artwork_transactions.drop(['eval_price_min'],axis=1,inplace=True)
artwork_transactions.drop(['eval_price_max'],axis=1,inplace=True)
artwork_transactions.drop(['eval_price'],axis=1,inplace=True)
artwork_transactions.drop(['auction_id'],axis=1,inplace=True)



calc_price = artwork_transactions['calc_price']
artwork_transactions.drop(['calc_price'],axis=1,inplace=True)

# %%
artwork_transactions.head()
# Out:
#   trans_category trans_art_type  transaction_date  company_id  artist
# 0             绘画           中国书画        1387641600         129  117629
# 1             书法           中国书画        1134230400          72   15710
# 2             书法           中国书画        1370188800           7   14567
# 3             绘画           中国书画        1399564800          67   42533
# 4             绘画           中国书画        1290009600         233   47595

# %%
category_attrib = ['trans_category', 'trans_art_type', 'company_id', 'artist']

# %%
artwork_transactions['company_id'] = artwork_transactions['company_id'].astype(str)
artwork_transactions['artist'] = artwork_transactions['artist'].astype(str)

# %%
serial_attrib = ['transaction_date']

# %%
#artwork_transactions['eval_price'] = scale(artwork_transactions['eval_price'])
artwork_transactions['transaction_datee'] = scale(artwork_transactions['transaction_date'])
# Out:
# /Users/eva/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by the scale function.
#   warnings.warn(msg, DataConversionWarning)
# /Users/eva/anaconda3/lib/python3.6/site-packages/sklearn/preprocessing/data.py:164: UserWarning: Numerical issues were encountered when centering the data and might not be solved. Dataset may contain too large values. You may need to prescale your features.
#   warnings.warn("Numerical issues were encountered "

# %%
columns = []
for column_name in artwork_transactions:
    columns.append(artwork_transactions[column_name])

feature_tuple = list(zip(*columns))
feature_dic = [{k: v for k,v in zip(attrib, d)} for d in feature_tuple]

# %%
feature_dic
# Out:
# [{'artist': '117629',
#   'company_id': '129',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1387641600},
#  {'artist': '15710',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1134230400},
#  {'artist': '14567',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1370188800},
#  {'artist': '42533',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1399564800},
#  {'artist': '47595',
#   'company_id': '233',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1290009600},
#  {'artist': '77399',
#   'company_id': '123',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1274457600},
#  {'artist': '92880',
#   'company_id': '175',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1146412800},
#  {'artist': '6792',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1398960000},
#  {'artist': '24495',
#   'company_id': '225',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1398441600},
#  {'artist': '71720',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1261411200},
#  {'artist': '9508',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1088179200},
#  {'artist': '26081',
#   'company_id': '116',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1352476800},
#  {'artist': '102941',
#   'company_id': '64',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1260806400},
#  {'artist': '99644',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1184342400},
#  {'artist': '15337',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1323964800},
#  {'artist': '15504',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1184342400},
#  {'artist': '82207',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400256000},
#  {'artist': '30430',
#   'company_id': '302',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1226937600},
#  {'artist': '1016',
#   'company_id': '176',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1100620800},
#  {'artist': '83240',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1189699200},
#  {'artist': '102268',
#   'company_id': '44',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1348156800},
#  {'artist': '100030',
#   'company_id': '421',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1422633600},
#  {'artist': '7245',
#   'company_id': '191',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1277827200},
#  {'artist': '43984',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1389196800},
#  {'artist': '12153',
#   'company_id': '283',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1370534400},
#  {'artist': '103355',
#   'company_id': '398',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1150473600},
#  {'artist': '114345',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1196438400},
#  {'artist': '40505',
#   'company_id': '216',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1339084800},
#  {'artist': '120790',
#   'company_id': '381',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1326470400},
#  {'artist': '18028',
#   'company_id': '335',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1415894400},
#  {'artist': '21681',
#   'company_id': '46',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1355241600},
#  {'artist': '113494',
#   'company_id': '253',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1358524800},
#  {'artist': '96146',
#   'company_id': '160',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1100102400},
#  {'artist': '37712',
#   'company_id': '168',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1357920000},
#  {'artist': '86000',
#   'company_id': '4',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1227715200},
#  {'artist': '67670',
#   'company_id': '216',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1346428800},
#  {'artist': '84151',
#   'company_id': '305',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1182528000},
#  {'artist': '38860',
#   'company_id': '253',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1324656000},
#  {'artist': '43970',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1323792000},
#  {'artist': '99866',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1356537600},
#  {'artist': '35720',
#   'company_id': '101',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1365091200},
#  {'artist': '89904',
#   'company_id': '30',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1396713600},
#  {'artist': '101178',
#   'company_id': '102',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1321286400},
#  {'artist': '59040',
#   'company_id': '133',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1387209600},
#  {'artist': '13223',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1213372800},
#  {'artist': '107039',
#   'company_id': '125',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1276704000},
#  {'artist': '39691',
#   'company_id': '236',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1291132800},
#  {'artist': '14791',
#   'company_id': '342',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1399046400},
#  {'artist': '89797',
#   'company_id': '322',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1308931200},
#  {'artist': '13223',
#   'company_id': '120',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1431619200},
#  {'artist': '53890',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1334073600},
#  {'artist': '21181',
#   'company_id': '443',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1346342400},
#  {'artist': '109599',
#   'company_id': '4',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1238601600},
#  {'artist': '87808',
#   'company_id': '3',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1113667200},
#  {'artist': '96661',
#   'company_id': '335',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1345824000},
#  {'artist': '50147',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1157644800},
#  {'artist': '19531',
#   'company_id': '78',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1336838400},
#  {'artist': '28471',
#   'company_id': '13',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1083945600},
#  {'artist': '37361',
#   'company_id': '248',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1134489600},
#  {'artist': '98986',
#   'company_id': '152',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1189958400},
#  {'artist': '14711',
#   'company_id': '151',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1310140800},
#  {'artist': '36258',
#   'company_id': '152',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1211990400},
#  {'artist': '13223',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1378396800},
#  {'artist': '114345',
#   'company_id': '268',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1333036800},
#  {'artist': '62966',
#   'company_id': '111',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1317916800},
#  {'artist': '71720',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1261152000},
#  {'artist': '56237',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1374768000},
#  {'artist': '45467',
#   'company_id': '294',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1213977600},
#  {'artist': '87433',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1344441600},
#  {'artist': '114908',
#   'company_id': '14',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1287763200},
#  {'artist': '74607',
#   'company_id': '200',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1294675200},
#  {'artist': '31698',
#   'company_id': '123',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1251388800},
#  {'artist': '86576',
#   'company_id': '587',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1305475200},
#  {'artist': '34631',
#   'company_id': '50',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1305129600},
#  {'artist': '44579',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1378828800},
#  {'artist': '13163',
#   'company_id': '305',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '雕塑',
#   'transaction_date': 1386950400},
#  {'artist': '106247',
#   'company_id': '5',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1419609600},
#  {'artist': '19317',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1145376000},
#  {'artist': '43970',
#   'company_id': '293',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1293206400},
#  {'artist': '77981',
#   'company_id': '3',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1238428800},
#  {'artist': '98986',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1158249600},
#  {'artist': '89908',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1181923200},
#  {'artist': '46904',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1337961600},
#  {'artist': '47595',
#   'company_id': '291',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1228406400},
#  {'artist': '31698',
#   'company_id': '14',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1224259200},
#  {'artist': '82207',
#   'company_id': '260',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1214323200},
#  {'artist': '9508',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1291219200},
#  {'artist': '54869',
#   'company_id': '84',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1293638400},
#  {'artist': '113846',
#   'company_id': '26',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1386172800},
#  {'artist': '73753',
#   'company_id': '92',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1308153600},
#  {'artist': '49556',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1319385600},
#  {'artist': '67320',
#   'company_id': '17',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1253808000},
#  {'artist': '38638',
#   'company_id': '114',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1340812800},
#  {'artist': '24183',
#   'company_id': '41',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1309536000},
#  {'artist': '112998',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1289836800},
#  {'artist': '18959',
#   'company_id': '148',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400083200},
#  {'artist': '71720',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1305734400},
#  {'artist': '67363',
#   'company_id': '163',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1323100800},
#  {'artist': '50602',
#   'company_id': '104',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1200067200},
#  {'artist': '25576',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1131033600},
#  {'artist': '98227',
#   'company_id': '97',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1332950400},
#  {'artist': '871',
#   'company_id': '45',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1133366400},
#  {'artist': '39226',
#   'company_id': '215',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1137168000},
#  {'artist': '100234',
#   'company_id': '157',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1341504000},
#  {'artist': '18028',
#   'company_id': '248',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1420819200},
#  {'artist': '19098',
#   'company_id': '251',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1146153600},
#  {'artist': '12852',
#   'company_id': '104',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1231084800},
#  {'artist': '28703',
#   'company_id': '233',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1164988800},
#  {'artist': '14944',
#   'company_id': '566',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1165248000},
#  {'artist': '105035',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1275062400},
#  {'artist': '98986',
#   'company_id': '148',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1130947200},
#  {'artist': '13329',
#   'company_id': '30',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '雕塑',
#   'transaction_date': 1380902400},
#  {'artist': '56522',
#   'company_id': '104',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1231084800},
#  {'artist': '19462',
#   'company_id': '272',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1382716800},
#  {'artist': '92164',
#   'company_id': '408',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1287158400},
#  {'artist': '75385',
#   'company_id': '125',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1276704000},
#  {'artist': '93531',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1348588800},
#  {'artist': '45612',
#   'company_id': '104',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1126368000},
#  {'artist': '15504',
#   'company_id': '139',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1295020800},
#  {'artist': '69756',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1291996800},
#  {'artist': '18028',
#   'company_id': '663',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1370793600},
#  {'artist': '63125',
#   'company_id': '2',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1275062400},
#  {'artist': '28896',
#   'company_id': '73',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1071244800},
#  {'artist': '104460',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1258819200},
#  {'artist': '48056',
#   'company_id': '109',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1136476800},
#  {'artist': '49556',
#   'company_id': '29',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1277395200},
#  {'artist': '102272',
#   'company_id': '18',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1346947200},
#  {'artist': '14741',
#   'company_id': '17',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1151251200},
#  {'artist': '28703',
#   'company_id': '121',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1340380800},
#  {'artist': '115917',
#   'company_id': '89',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1417708800},
#  {'artist': '37081',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1180195200},
#  {'artist': '87808',
#   'company_id': '129',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1119628800},
#  {'artist': '87004',
#   'company_id': '427',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1387296000},
#  {'artist': '60341',
#   'company_id': '238',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1369411200},
#  {'artist': '82207',
#   'company_id': '198',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1304179200},
#  {'artist': '57403',
#   'company_id': '326',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1395936000},
#  {'artist': '67093',
#   'company_id': '191',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1071417600},
#  {'artist': '24942',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1307203200},
#  {'artist': '84747',
#   'company_id': '124',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1283443200},
#  {'artist': '40505',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1290096000},
#  {'artist': '84099',
#   'company_id': '30',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1349452800},
#  {'artist': '82207',
#   'company_id': '13',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1322150400},
#  {'artist': '56081',
#   'company_id': '146',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': 'unclear',
#   'transaction_date': 1434643200},
#  {'artist': '44843',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1198252800},
#  {'artist': '101823',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1229184000},
#  {'artist': '119802',
#   'company_id': '84',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400688000},
#  {'artist': '14923',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1364054400},
#  {'artist': '67093',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1092844800},
#  {'artist': '28366',
#   'company_id': '63',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1253116800},
#  {'artist': '117477',
#   'company_id': '272',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1398441600},
#  {'artist': '83376',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1389974400},
#  {'artist': '26081',
#   'company_id': '171',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1087574400},
#  {'artist': '88641',
#   'company_id': '296',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1401465600},
#  {'artist': '115216',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1259424000},
#  {'artist': '49053',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1275235200},
#  {'artist': '94085',
#   'company_id': '583',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1340380800},
#  {'artist': '64236',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1369929600},
#  {'artist': '3193',
#   'company_id': '283',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1370534400},
#  {'artist': '6757',
#   'company_id': '320',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1165593600},
#  {'artist': '56042',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1261411200},
#  {'artist': '38558',
#   'company_id': '191',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1341936000},
#  {'artist': '72160',
#   'company_id': '97',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1269532800},
#  {'artist': '30763',
#   'company_id': '379',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1417795200},
#  {'artist': '82070',
#   'company_id': '14',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1349798400},
#  {'artist': '37290',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1416758400},
#  {'artist': '347',
#   'company_id': '41',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1309536000},
#  {'artist': '78222',
#   'company_id': '30',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1223136000},
#  {'artist': '114720',
#   'company_id': '620',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1417104000},
#  {'artist': '40505',
#   'company_id': '779',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1330704000},
#  {'artist': '14944',
#   'company_id': '155',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1418918400},
#  {'artist': '61222',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1159286400},
#  {'artist': '82663',
#   'company_id': '621',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1377187200},
#  {'artist': '56618',
#   'company_id': '36',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1397145600},
#  {'artist': '68972',
#   'company_id': '164',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400774400},
#  {'artist': '87433',
#   'company_id': '296',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1369843200},
#  {'artist': '52042',
#   'company_id': '116',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1394812800},
#  {'artist': '52222',
#   'company_id': '163',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1323100800},
#  {'artist': '12892',
#   'company_id': '178',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1357228800},
#  {'artist': '21739',
#   'company_id': '2',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1290787200},
#  {'artist': '78449',
#   'company_id': '235',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1164729600},
#  {'artist': '53434',
#   'company_id': '586',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1373817600},
#  {'artist': '87433',
#   'company_id': '155',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1383926400},
#  {'artist': '84352',
#   'company_id': '45',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1133366400},
#  {'artist': '70675',
#   'company_id': '191',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1301587200},
#  {'artist': '8050',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1197993600},
#  {'artist': '113606',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1276876800},
#  {'artist': '7789',
#   'company_id': '77',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1292256000},
#  {'artist': '13223',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1105545600},
#  {'artist': '90180',
#   'company_id': '30',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1333209600},
#  {'artist': '26657',
#   'company_id': '125',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1387036800},
#  {'artist': '102960',
#   'company_id': '95',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1261756800},
#  {'artist': '98986',
#   'company_id': '114',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1142352000},
#  {'artist': '52038',
#   'company_id': '86',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1368201600},
#  {'artist': '71839',
#   'company_id': '131',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1278000000},
#  {'artist': '40647',
#   'company_id': '296',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1401465600},
#  {'artist': '67546',
#   'company_id': '148',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1150732800},
#  {'artist': '80283',
#   'company_id': '151',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1186761600},
#  {'artist': '14944',
#   'company_id': '525',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1422028800},
#  {'artist': '51475',
#   'company_id': '173',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1267804800},
#  {'artist': '47692',
#   'company_id': '198',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1335542400},
#  {'artist': '115454',
#   'company_id': '110',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1356710400},
#  {'artist': '81619',
#   'company_id': '173',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1194019200},
#  {'artist': '91137',
#   'company_id': '133',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1419436800},
#  {'artist': '98986',
#   'company_id': '218',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1303660800},
#  {'artist': '347',
#   'company_id': '216',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1372348800},
#  {'artist': '78928',
#   'company_id': '40',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1137168000},
#  {'artist': '106614',
#   'company_id': '216',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1313942400},
#  {'artist': '15051',
#   'company_id': '183',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1397145600},
#  {'artist': '118822',
#   'company_id': '150',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1231516800},
#  {'artist': '97650',
#   'company_id': '17',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1117900800},
#  {'artist': '12047',
#   'company_id': '338',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1380124800},
#  {'artist': '77627',
#   'company_id': '101',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1385136000},
#  {'artist': '5498',
#   'company_id': '42',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1197043200},
#  {'artist': '14986',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1252684800},
#  {'artist': '1944',
#   'company_id': '111',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1353600000},
#  {'artist': '104179',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1142006400},
#  {'artist': '72643',
#   'company_id': '119',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1383926400},
#  {'artist': '78412',
#   'company_id': '164',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400774400},
#  {'artist': '9508',
#   'company_id': '308',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1127404800},
#  {'artist': '37832',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1180454400},
#  {'artist': '44579',
#   'company_id': '64',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1260806400},
#  {'artist': '94004',
#   'company_id': '429',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1299254400},
#  {'artist': '12620',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1273766400},
#  {'artist': '35320',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1427817600},
#  {'artist': '40536',
#   'company_id': '583',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1406304000},
#  {'artist': '113206',
#   'company_id': '154',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1318953600},
#  {'artist': '29219',
#   'company_id': '2',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 893433600},
#  {'artist': '20985',
#   'company_id': '261',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1373558400},
#  {'artist': '871',
#   'company_id': '104',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1126368000},
#  {'artist': '21656',
#   'company_id': '89',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '版画',
#   'transaction_date': 1306857600},
#  {'artist': '112967',
#   'company_id': '125',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1387036800},
#  {'artist': '99634',
#   'company_id': '2',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1290873600},
#  {'artist': '86938',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1300464000},
#  {'artist': '13308',
#   'company_id': '36',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1428595200},
#  {'artist': '23326',
#   'company_id': '60',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1321632000},
#  {'artist': '52560',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1184947200},
#  {'artist': '43970',
#   'company_id': '157',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1322236800},
#  {'artist': '72521',
#   'company_id': '156',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1316016000},
#  {'artist': '9728',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1035561600},
#  {'artist': '88980',
#   'company_id': '45',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1231430400},
#  {'artist': '88366',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1194192000},
#  {'artist': '112998',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1326038400},
#  {'artist': '37827',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1318348800},
#  {'artist': '24989',
#   'company_id': '156',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1334764800},
#  {'artist': '92587',
#   'company_id': '148',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1117814400},
#  {'artist': '38793',
#   'company_id': '196',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '西画雕塑其它',
#   'transaction_date': 1337356800},
#  {'artist': '110231',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1373040000},
#  {'artist': '68631',
#   'company_id': '38',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1322755200},
#  {'artist': '40647',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1210262400},
#  {'artist': '99224',
#   'company_id': '248',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1386259200},
#  {'artist': '36535',
#   'company_id': '176',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1100534400},
#  {'artist': '67239',
#   'company_id': '89',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1322323200},
#  {'artist': '87433',
#   'company_id': '86',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1385740800},
#  {'artist': '24942',
#   'company_id': '47',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1323446400},
#  {'artist': '20339',
#   'company_id': '268',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1333036800},
#  {'artist': '17429',
#   'company_id': '679',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400947200},
#  {'artist': '107649',
#   'company_id': '241',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '综合媒材',
#   'transaction_date': 1324656000},
#  {'artist': '56583',
#   'company_id': '136',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1227801600},
#  {'artist': '77399',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400947200},
#  {'artist': '43970',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1433520000},
#  {'artist': '64562',
#   'company_id': '139',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1402070400},
#  {'artist': '104552',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1385913600},
#  {'artist': '31698',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1276790400},
#  {'artist': '28896',
#   'company_id': '328',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '版画',
#   'transaction_date': 1411747200},
#  {'artist': '32727',
#   'company_id': '54',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '雕塑',
#   'transaction_date': 1344009600},
#  {'artist': '44826',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1291996800},
#  {'artist': '93960',
#   'company_id': '30',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1238774400},
#  {'artist': '10628',
#   'company_id': '84',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1385049600},
#  {'artist': '43359',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1243526400},
#  {'artist': '11319',
#   'company_id': '328',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '水粉水彩',
#   'transaction_date': 1318003200},
#  {'artist': '58460',
#   'company_id': '73',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1117209600},
#  {'artist': '84353',
#   'company_id': '97',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1332950400},
#  {'artist': '80599',
#   'company_id': '113',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1335456000},
#  {'artist': '15258',
#   'company_id': '137',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1389110400},
#  {'artist': '28471',
#   'company_id': '17',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1351008000},
#  {'artist': '19317',
#   'company_id': '154',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1136563200},
#  {'artist': '82595',
#   'company_id': '526',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1101225600},
#  {'artist': '20937',
#   'company_id': '14',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1397232000},
#  {'artist': '103',
#   'company_id': '2',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '综合媒材',
#   'transaction_date': 1019836800},
#  {'artist': '22458',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1278172800},
#  {'artist': '13589',
#   'company_id': '602',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1133280000},
#  {'artist': '71676',
#   'company_id': '65',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1384704000},
#  {'artist': '9508',
#   'company_id': '164',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1257523200},
#  {'artist': '66799',
#   'company_id': '658',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1345132800},
#  {'artist': '88980',
#   'company_id': '237',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1334937600},
#  {'artist': '26223',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1386950400},
#  {'artist': '55656',
#   'company_id': '233',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1260633600},
#  {'artist': '31028',
#   'company_id': '116',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1373904000},
#  {'artist': '28619',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1292601600},
#  {'artist': '16317',
#   'company_id': '108',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1344614400},
#  {'artist': '89290',
#   'company_id': '148',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1132761600},
#  {'artist': '75426',
#   'company_id': '4',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1169740800},
#  {'artist': '123053',
#   'company_id': '110',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1377792000},
#  {'artist': '89908',
#   'company_id': '152',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1200240000},
#  {'artist': '76872',
#   'company_id': '45',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1320336000},
#  {'artist': '120639',
#   'company_id': '60',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1321632000},
#  {'artist': '22458',
#   'company_id': '174',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1372348800},
#  {'artist': '78412',
#   'company_id': '187',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1262016000},
#  {'artist': '99524',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1292515200},
#  {'artist': '28471',
#   'company_id': '188',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1340380800},
#  {'artist': '78449',
#   'company_id': '163',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1403884800},
#  {'artist': '48053',
#   'company_id': '148',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1131033600},
#  {'artist': '87433',
#   'company_id': '236',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1357315200},
#  {'artist': '73253',
#   'company_id': '183',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1323446400},
#  {'artist': '8629',
#   'company_id': '45',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1255708800},
#  {'artist': '96993',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1421942400},
#  {'artist': '107047',
#   'company_id': '97',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1416844800},
#  {'artist': '47595',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1291478400},
#  {'artist': '26920',
#   'company_id': '764',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1269014400},
#  {'artist': '67631',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1386864000},
#  {'artist': '30601',
#   'company_id': '200',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1355155200},
#  {'artist': '117782',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1284739200},
#  {'artist': '14944',
#   'company_id': '143',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1409328000},
#  {'artist': '106060',
#   'company_id': '151',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1420819200},
#  {'artist': '68780',
#   'company_id': '13',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1131379200},
#  {'artist': '76838',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1119024000},
#  {'artist': '10623',
#   'company_id': '151',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1288281600},
#  {'artist': '10229',
#   'company_id': '114',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1352908800},
#  {'artist': '111891',
#   'company_id': '17',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1250870400},
#  {'artist': '9365',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1320940800},
#  {'artist': '89206',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1081353600},
#  {'artist': '108831',
#   'company_id': '116',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1363449600},
#  {'artist': '72961',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1300636800},
#  {'artist': '57046',
#   'company_id': '417',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1337961600},
#  {'artist': '60590',
#   'company_id': '133',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1434470400},
#  {'artist': '102268',
#   'company_id': '64',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1323014400},
#  {'artist': '43970',
#   'company_id': '208',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1276704000},
#  {'artist': '35320',
#   'company_id': '186',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1400256000},
#  {'artist': '71720',
#   'company_id': '3',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1073059200},
#  {'artist': '71890',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1397923200},
#  {'artist': '81183',
#   'company_id': '64',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1355587200},
#  {'artist': '69152',
#   'company_id': '578',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1323446400},
#  {'artist': '7862',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1142006400},
#  {'artist': '37827',
#   'company_id': '151',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1275667200},
#  {'artist': '81103',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1148054400},
#  {'artist': '58075',
#   'company_id': '217',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1082044800},
#  {'artist': '67302',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1395504000},
#  {'artist': '20900',
#   'company_id': '216',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1339084800},
#  {'artist': '115667',
#   'company_id': '45',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1196352000},
#  {'artist': '111514',
#   'company_id': '488',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1347206400},
#  {'artist': '38062',
#   'company_id': '73',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1131638400},
#  {'artist': '14944',
#   'company_id': '73',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1212076800},
#  {'artist': '100973',
#   'company_id': '6',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1253808000},
#  {'artist': '102272',
#   'company_id': '56',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1165593600},
#  {'artist': '33138',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1243094400},
#  {'artist': '114050',
#   'company_id': '226',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1324483200},
#  {'artist': '35320',
#   'company_id': '296',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1353513600},
#  {'artist': '441',
#   'company_id': '89',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '版画',
#   'transaction_date': 1401292800},
#  {'artist': '67905',
#   'company_id': '678',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1132761600},
#  {'artist': '34801',
#   'company_id': '148',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1142006400},
#  {'artist': '98598',
#   'company_id': '97',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1365091200},
#  {'artist': '7789',
#   'company_id': '578',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1323446400},
#  {'artist': '102145',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1179417600},
#  {'artist': '24495',
#   'company_id': '151',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1164988800},
#  {'artist': '48298',
#   'company_id': '237',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1355500800},
#  {'artist': '47371',
#   'company_id': '239',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1356105600},
#  {'artist': '121887',
#   'company_id': '512',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1406649600},
#  {'artist': '92895',
#   'company_id': '330',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1374854400},
#  {'artist': '73968',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1315929600},
#  {'artist': '116849',
#   'company_id': '367',
# ...
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1372348800},
#  {'artist': '28896',
#   'company_id': '30',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1035648000},
#  {'artist': '52228',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1126281600},
#  {'artist': '35320',
#   'company_id': '234',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1272038400},
#  {'artist': '18443',
#   'company_id': '268',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1348761600},
#  {'artist': '82207',
#   'company_id': '4',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1337875200},
#  {'artist': '82207',
#   'company_id': '29',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1260460800},
#  {'artist': '81311',
#   'company_id': '418',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1332345600},
#  {'artist': '60590',
#   'company_id': '17',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1133366400},
#  {'artist': '45780',
#   'company_id': '129',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1403884800},
#  {'artist': '91042',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1134748800},
#  {'artist': '24937',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1325088000},
#  {'artist': '49093',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1311609600},
#  {'artist': '12891',
#   'company_id': '717',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400860800},
#  {'artist': '78483',
#   'company_id': '160',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1071676800},
#  {'artist': '34767',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1338652800},
#  {'artist': '110902',
#   'company_id': '131',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1278000000},
#  {'artist': '120720',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1275494400},
#  {'artist': '28136',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1179504000},
#  {'artist': '100877',
#   'company_id': '248',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1134576000},
#  {'artist': '82539',
#   'company_id': '116',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1363449600},
#  {'artist': '98598',
#   'company_id': '275',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1209052800},
#  {'artist': '4482',
#   'company_id': '45',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1355500800},
#  {'artist': '77399',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1104336000},
#  {'artist': '108834',
#   'company_id': '233',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1260633600},
#  {'artist': '96892',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1099065600},
#  {'artist': '19069',
#   'company_id': '586',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1405008000},
#  {'artist': '119621',
#   'company_id': '104',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1247932800},
#  {'artist': '84610',
#   'company_id': '54',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1368720000},
#  {'artist': '22458',
#   'company_id': '108',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1375891200},
#  {'artist': '98986',
#   'company_id': '173',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1249056000},
#  {'artist': '40505',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1190304000},
#  {'artist': '66770',
#   'company_id': '26',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1364227200},
#  {'artist': '111368',
#   'company_id': '275',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1178812800},
#  {'artist': '116674',
#   'company_id': '72',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '版画',
#   'transaction_date': 1245945600},
#  {'artist': '4426',
#   'company_id': '78',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1290182400},
#  {'artist': '88853',
#   'company_id': '151',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1136822400},
#  {'artist': '6629',
#   'company_id': '379',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1307116800},
#  {'artist': '87626',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1111680000},
#  {'artist': '9365',
#   'company_id': '220',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1419004800},
#  {'artist': '59133',
#   'company_id': '31',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1381420800},
#  {'artist': '8059',
#   'company_id': '154',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1338307200},
#  {'artist': '13492',
#   'company_id': '104',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1231084800},
#  {'artist': '35320',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1273939200},
#  {'artist': '46904',
#   'company_id': '124',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1283443200},
#  {'artist': '85915',
#   'company_id': '200',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1239379200},
#  {'artist': '108986',
#   'company_id': '324',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1335456000},
#  {'artist': '77399',
#   'company_id': '291',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1260806400},
#  {'artist': '62150',
#   'company_id': '349',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1348761600},
#  {'artist': '67356',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1261065600},
#  {'artist': '15440',
#   'company_id': '77',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1329408000},
#  {'artist': '115359',
#   'company_id': '204',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1256313600},
#  {'artist': '94653',
#   'company_id': '14',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1228406400},
#  {'artist': '98875',
#   'company_id': '381',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1271433600},
#  {'artist': '91821',
#   'company_id': '248',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1339171200},
#  {'artist': '69434',
#   'company_id': '38',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1352476800},
#  {'artist': '105691',
#   'company_id': '138',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1435420800},
#  {'artist': '28605',
#   'company_id': '67',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1134144000},
#  {'artist': '102268',
#   'company_id': '103',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '素描',
#   'transaction_date': 1310140800},
#  {'artist': '73135',
#   'company_id': '164',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1240588800},
#  {'artist': '152',
#   'company_id': '367',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1165420800},
#  {'artist': '114813',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1400947200},
#  {'artist': '122202',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1180713600},
#  {'artist': '50449',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1336665600},
#  {'artist': '56321',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1168531200},
#  {'artist': '35397',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1071158400},
#  {'artist': '97193',
#   'company_id': '379',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1356105600},
#  {'artist': '40505',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1276790400},
#  {'artist': '82412',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1273766400},
#  {'artist': '24942',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1209139200},
#  {'artist': '36535',
#   'company_id': '176',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1038844800},
#  {'artist': '56834',
#   'company_id': '3',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1240761600},
#  {'artist': '88641',
#   'company_id': '300',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1317139200},
#  {'artist': '115449',
#   'company_id': '421',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1422633600},
#  {'artist': '15021',
#   'company_id': '72',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1087920000},
#  {'artist': '14841',
#   'company_id': '129',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1387641600},
#  {'artist': '86156',
#   'company_id': '121',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1340380800},
#  {'artist': '96724',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1223481600},
#  {'artist': '22509',
#   'company_id': '125',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1294156800},
#  {'artist': '38638',
#   'company_id': '129',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1292256000},
#  {'artist': '53708',
#   'company_id': '7',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1354723200},
#  {'artist': '114260',
#   'company_id': '494',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1145635200},
#  {'artist': '16211',
#   'company_id': '56',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1156521600},
#  {'artist': '114345',
#   'company_id': '77',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1403625600},
#  {'artist': '41118',
#   'company_id': '207',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1323446400},
#  {'artist': '37799',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1164470400},
#  {'artist': '44826',
#   'company_id': '191',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1261497600},
#  {'artist': '55963',
#   'company_id': '798',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1323360000},
#  {'artist': '16521',
#   'company_id': '187',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1136822400},
#  {'artist': '69677',
#   'company_id': '190',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1382371200},
#  {'artist': '9508',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1291824000},
#  {'artist': '69311',
#   'company_id': '191',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1135094400},
#  {'artist': '35320',
#   'company_id': '198',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1288281600},
#  {'artist': '118542',
#   'company_id': '53',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1245340800},
#  {'artist': '43970',
#   'company_id': '291',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1276963200},
#  {'artist': '53578',
#   'company_id': '398',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1194019200},
#  {'artist': '24495',
#   'company_id': '139',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1371744000},
#  {'artist': '83455',
#   'company_id': '199',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1403280000},
#  {'artist': '97650',
#   'company_id': '42',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1305907200},
#  {'artist': '98986',
#   'company_id': '127',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1369497600},
#  {'artist': '98875',
#   'company_id': '153',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1199462400},
#  {'artist': '62927',
#   'company_id': '176',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1100534400},
#  {'artist': '24213',
#   'company_id': '53',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1356710400},
#  {'artist': '86833',
#   'company_id': '6',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1292083200},
#  {'artist': '80075',
#   'company_id': '64',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1371139200},
#  {'artist': '89856',
#   'company_id': '67',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1305734400},
#  {'artist': '89856',
#   'company_id': '176',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1100620800},
#  {'artist': '101102',
#   'company_id': '527',
#   'trans_art_type': '西画雕塑',
#   'trans_cantegory': '油画',
#   'transaction_date': 1195833600},
#  {'artist': '29789',
#   'company_id': '173',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1309795200},
#  {'artist': '52042',
#   'company_id': '114',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1325001600},
#  {'artist': '71720',
#   'company_id': '316',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1310140800},
#  {'artist': '15455',
#   'company_id': '2',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1353859200},
#  {'artist': '121697',
#   'company_id': '163',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1323100800},
#  {'artist': '28471',
#   'company_id': '89',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1306857600},
#  {'artist': '61672',
#   'company_id': '307',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1397836800},
#  {'artist': '5516',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1354550400},
#  {'artist': '102272',
#   'company_id': '21',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1380124800},
#  {'artist': '114345',
#   'company_id': '9',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1344528000},
#  {'artist': '5388',
#   'company_id': '116',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '绘画',
#   'transaction_date': 1363449600},
#  {'artist': '114189',
#   'company_id': '92',
#   'trans_art_type': '中国书画',
#   'trans_cantegory': '书法',
#   'transaction_date': 1321891200},
#  ...]

# %%
from sklearn.feature_extraction import DictVectorizer
victorizer = DictVectorizer(sparse = True)
feature_matric = victorizer.fit_transform(feature_dic)
feature_matric = feature_matric.toarray()

# %%
feature_matric
# Out:
# array([[  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   1.38764160e+09],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   1.13423040e+09],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   1.37018880e+09],
#        ...,
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   1.16438400e+09],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   1.35852480e+09],
#        [  0.00000000e+00,   0.00000000e+00,   0.00000000e+00, ...,
#           0.00000000e+00,   0.00000000e+00,   1.21337280e+09]])

# %%
label_train, label_test = sperate_train_data(calc_price)
feature_train, feature_test = sperate_train_data(feature_matric)

#label_test = label_test.reset_index()

label = calc_price
feature = feature_matric

# %%
from sklearn import tree
from sklearn.metrics import accuracy_score

dt = tree.DecisionTreeRegressor()#(min_samples_split= 400)
dt = dt.fit(feature_train, label_train)
pred_dt = dt.predict(feature_test)

# %%
print(len(label_test),len(feature_test))
print(len(label),len(feature))
# Out:
# 10541 10541
# 52704 52704

# %%
dt.score(feature_test, label_test)
# Out:
# -0.53874856575399366

# %%
importances = dt.feature_importances_
print(importances.argsort())
# Out:
# [ 5149 10766  5134 ...,   747 11546 10976]

# %%
# from sklearn.naive_bayes import GaussianNB
# gnb = GaussianNB()
# gnb = gnb.fit(feature_train, label_train)
# pred_gnb = gnb.predict(feature_test)
# pred2_gnb = gnb.predict(feature_train)
# print(accuracy_score(label_test, pred_gnb), accuracy_score(label_train, pred2_gnb))
